# %%
from astrapy import DataAPIClient

db_end_point = 'https://d1091311-1ba8-4970-bd74-937d6cda55b0-us-east-2.apps.astra.datastax.com'
db_token = '' # Add your database token here

client_db_read = DataAPIClient()
database = client_db_read.get_database(db_end_point, token=db_token)

table = database.get_table("news_sentiment")

cursor = table.find({})

lis1 = []
for row in cursor:
    lis1.append(row)
